# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import json

# %% [markdown]
# #Load data

# %%
df = pd.read_csv('/train_final_Task6.csv')

# Rename columns to match your format
new_df = df[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'})
print(new_df)
updated_input=[]
for line in new_df['input']:
  if ':' in line:
    newline=':'.join(line.strip().split(':')[1:])
    updated_input.append(newline)
  else:
    updated_input.append(line)
new_df['input']=updated_input
new_df['output']=new_df['output'].astype(str)
print(new_df)
new_df.to_csv('train_final_Task6.csv',index=False)
# Count the positive and negative cases in the 'output' column
label_counts = new_df['output'].value_counts()

print("Label counts:")
print(label_counts)
# Out:
#                                                   input  output
# 0     Shingles Vaccine: Warning, this post contains ...       1
# 1     Going to get my 2nd shingles shot in 15 minute...       1
# 2     Just got my flu shot and now experiencing some...       1
# 3     Has anyone experienced a strong reaction to th...       1
# 4     Getting two vaccines at once: I have a very re...       1
# ...                                                 ...     ...
# 3302  9 Health Related Issues Linked to HSV: This is...       0
# 3303  Cyclosporine advice questions: While topicals ...       0
# 3304  [FR] Comfort Test due to abundance: We will re...       0
# 3305  I beat cancer but my eating disorder is slowly...       0
# 3306  Getting estimates for roof - some questions an...       0
#
# [3307 rows x 2 columns]
#                                                   input output
# 0      Warning, this post contains an optimistic ant...      1
# ...

# %%
# Check if the dataset is balance

#%cd /content/drive/MyDrive/SMM4H/Task6/
#%cd /work/08315/fs0199/ls6/smm4h
# %cd /home1/00000/abcde/work/LLaMA-Factory/data
df = pd.read_csv('train 1_Task6.csv')

# Rename columns to match your format
new_df = df[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'})
print(new_df)
updated_input=[]
for line in new_df['input']:
  if ':' in line:
    newline=':'.join(line.strip().split(':')[1:])
    updated_input.append(newline)
  else:
    updated_input.append(line)
new_df['input']=updated_input
new_df['output']=new_df['output'].astype(str)
print(new_df)
new_df.to_csv('train_new_Task6.csv',index=False)
# Count the positive and negative cases in the 'output' column
label_counts = new_df['output'].value_counts()

print("Label counts:")
print(label_counts)
# Out:
# /work/00000/abcde/LLaMA-Factory/data
#                                                   input  output
# 0     Shingles Vaccine: Warning, this post contains ...       1
# 1     Going to get my 2nd shingles shot in 15 minute...       1
# 2     Just got my flu shot and now experiencing some...       1
# 3     Has anyone experienced a strong reaction to th...       1
# 4     Getting two vaccines at once: I have a very re...       1
# ...                                                 ...     ...
# 2516  In chronic pain, would a head to toe screen he...       0
# 2517  Bacterial infection of the eye can cause Shing...       0
# 2518  Bronchitis, Strep, HSV. Shingles? SDT? HELP PL...       0
# 2519  Can a child get the shingles vaccine?: I was s...       0
# 2520  Recently diagnosed with UC and looking for adv...       0
#
# [2521 rows x 2 columns]
#                                                   input output
# 0      Warning, this post contains an optimistic ant...      1
# ...

# %%
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df = pd.read_csv('valid 1_Task6.csv')

# Rename columns to match your format
new_df = df[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'})
print(new_df)
updated_input=[]
for line in new_df['input']:
  if ':' in line:
    newline=':'.join(line.strip().split(':')[1:])
    updated_input.append(newline)
  else:
    updated_input.append(line)
new_df['input']=updated_input
new_df['output']=new_df['output'].astype(str)
print(new_df)
new_df.to_csv('valid_new_Task6.csv',index=False)
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
#                                                  input  output
# 0    1st shingles shot over 72 hours ago and still ...       1
# 1    Shingles Vaccine: I got it. Kicked my butt for...       1
# 2    Shingles vaccine: second dose: 2nd got me, fir...       1
# 3    Shingles vaccine: second dose: 2nd one was not...       1
# 4    Shingles vaccine: second dose: First one level...       1
# ..                                                 ...     ...
# 781  9 Health Related Issues Linked to HSV: This is...       0
# 782  Cyclosporine advice questions: While topicals ...       0
# 783  [FR] Comfort Test due to abundance: We will re...       0
# 784  I beat cancer but my eating disorder is slowly...       0
# 785  Getting estimates for roof - some questions an...       0
#
# [786 rows x 2 columns]
#                                                  input output
# 0                            Second shot sucks too....      1
# ...

# %% [markdown]
# **Zero**-shot prompt

# %%
import json
#%cd /content/drive/MyDrive/SMM4H/Task6/New
#%cd /work/08315/fs0199/ls6/smm4h
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df_zs = pd.read_csv('train_new_Task6.csv')

# Rename columns to match LlamaFactory format
#df_zs = df_zs[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Zero-shot instruction #Yes -> "1", No -> "0"
zero_shot_prompt = """Determine if a given Reddit post contains a personal mention of an adverse reaction to a shingles vaccine.
A personal mention means the post's author (or someone they mention) explicitly describes experiencing negative side effects after receiving the vaccine.
Posts that describe such firsthand vaccine side effects should be classified as '1'
Posts that only discuss vaccines in general or do not describe a specific individual's side effects should be classified as '0'
Provide your answer as either '1' or '0'"""

# Add prompt as in-context learning
df_zs['instruction'] = zero_shot_prompt
df_dict=df_zs.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_zs.to_json("train_zero_shot.json", orient="records", lines=True)
with open('train_zero_shot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_zs.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input  output  \
# 0   Warning, this post contains an optimistic ant...       1
# 1   second one didn't make me sick but I had a GI...       1
# 2  Just got my flu shot and now experiencing some...       1
# 3  Has anyone experienced a strong reaction to th...       1
# 4   I have a very reactive immune system. 1 vacci...       1
#
#                                          instruction
# 0  Determine if a given Reddit post contains a pe...
# 1  Determine if a given Reddit post contains a pe...
# 2  Determine if a given Reddit post contains a pe...
# 3  Determine if a given Reddit post contains a pe...
# ...

# %%
import json
#%cd /content/drive/MyDrive/SMM4H/Task6/
#%cd /work/08315/fs0199/ls6/smm4h
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df_zs = pd.read_csv('valid_new_Task6.csv')

# Rename columns to match LlamaFactory format
#df_zs = df_zs[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Zero-shot instruction #Yes -> "1", No -> "0"
zero_shot_prompt = """Determine if a given Reddit post contains a personal mention of an adverse reaction to a shingles vaccine.
A personal mention means the post's author (or someone they mention) explicitly describes experiencing negative side effects after receiving the vaccine.
Posts that describe such firsthand vaccine side effects should be classified as '1'
Posts that only discuss vaccines in general or do not describe a specific individual's side effects should be classified as '0'
Provide your answer as either '1' or '0'"""

# Add prompt as in-context learning
df_zs['instruction'] = zero_shot_prompt
df_dict=df_zs.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_zs.to_json("train_zero_shot.json", orient="records", lines=True)
with open('valid_zero_shot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_zs.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input  output  \
# 0                          Second shot sucks too....       1
# 1       I got it. Kicked my butt for about 36 hours.       1
# 2   second dose: 2nd got me, first was fine. YMMV...       1
# 3   second dose: 2nd one was not as bad as the fi...       1
# 4   second dose: First one leveled me; second one...       1
#
#                                          instruction
# 0  Determine if a given Reddit post contains a pe...
# 1  Determine if a given Reddit post contains a pe...
# 2  Determine if a given Reddit post contains a pe...
# 3  Determine if a given Reddit post contains a pe...
# ...

# %% [markdown]
# Few-Shot

# %%
#%cd /content/drive/MyDrive/SMM4H/Task6/New
#%cd /home/UNT/fs0199//LLaMA-Factory/data/smm4h/
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df_fs = pd.read_csv('train_new_Task6.csv')

# Rename columns to match LlamaFactory format
#df_fs = df_fs[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Few-shot instruction
few_shot_prompt = """Decide if a Reddit post is a personal account of adverse vaccine reactions (specifically for the shingles vaccine).
A personal adverse reaction mention means someone is describing their own or another individual's side effects after the shot.
If so, answer '1'; if not, answer '0'

Examples:
1. Post: 'Just got my second shingles vaccine and wow, what a ride! The first one was a breeze, but this time I had all the bells and whistles of side effects. Fingers crossed that it's all worth it in the end!' → 1
2. Post: 'What a Coincidence! Pushing the Shingles Jab now! Shingles one of the known side effects of the COVID Jab.' → 0

Now classify the following post accordingly:"""

# Add prompt as in-context learning
df_fs['instruction'] = few_shot_prompt
df_dict=df_fs.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_fs.to_json("train_few_shot.json", orient="records", lines=True)
with open('train_few_shot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_fs.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input  output  \
# 0   Warning, this post contains an optimistic ant...       1
# 1   second one didn't make me sick but I had a GI...       1
# 2  Just got my flu shot and now experiencing some...       1
# 3  Has anyone experienced a strong reaction to th...       1
# 4   I have a very reactive immune system. 1 vacci...       1
#
#                                          instruction
# 0  Decide if a Reddit post is a personal account ...
# 1  Decide if a Reddit post is a personal account ...
# 2  Decide if a Reddit post is a personal account ...
# 3  Decide if a Reddit post is a personal account ...
# ...

# %%
import json
#%cd /content/drive/MyDrive/SMM4H/Task6/
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df_fs = pd.read_csv('valid_new_Task6.csv')

# Rename columns to match LlamaFactory format
#df_fs = df_fs[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Few-shot instruction
few_shot_prompt = """Decide if a Reddit post is a personal account of adverse vaccine reactions (specifically for the shingles vaccine).
A personal adverse reaction mention means someone is describing their own or another individual's side effects after the shot.
If so, answer '1'; if not, answer '0'

Examples:
1. Post: 'Just got my second shingles vaccine and wow, what a ride! The first one was a breeze, but this time I had all the bells and whistles of side effects. Fingers crossed that it's all worth it in the end!' → 1
2. Post: 'What a Coincidence! Pushing the Shingles Jab now! Shingles one of the known side effects of the COVID Jab.' → 0

Now classify the following post accordingly:"""

# Add prompt as in-context learning
df_fs['instruction'] = few_shot_prompt
df_dict=df_fs.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_fs.to_json("train_few_shot.json", orient="records", lines=True)
with open('valid_few_shot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_fs.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input  output  \
# 0                          Second shot sucks too....       1
# 1       I got it. Kicked my butt for about 36 hours.       1
# 2   second dose: 2nd got me, first was fine. YMMV...       1
# 3   second dose: 2nd one was not as bad as the fi...       1
# 4   second dose: First one leveled me; second one...       1
#
#                                          instruction
# 0  Decide if a Reddit post is a personal account ...
# 1  Decide if a Reddit post is a personal account ...
# 2  Decide if a Reddit post is a personal account ...
# 3  Decide if a Reddit post is a personal account ...
# ...

# %% [markdown]
# CoT

# %%
#%cd /content/drive/MyDrive/SMM4H/Task6/
#%cd /home/UNT/fs0199//LLaMA-Factory/data/smm4h/
df_cot = pd.read_csv('train_final_Task6.csv')
print(df_cot)

# Rename columns to match LlamaFactory format
df_cot = df_cot[['input', 'output']]

# Chain-of-Thought instruction
cot_prompt = """Analyze the following Reddit post and determine if it contains a personal mention of an adverse reaction to the shingles vaccine.
Let's break down the reasoning step by step:

1. Identify if the post is written from personal experience (first-person or describing a specific individual).
2. Check if the post mentions any symptoms or side effects following a shingles vaccination.
3. If both conditions are met, the post is a personal adverse reaction account.

Finally, provide the classification as '1' (contains a personal adverse reaction mention) or '0' (does not), along with a brief explanation of your reasoning."""

# Add prompt as in-context learning
df_cot['instruction'] = cot_prompt
df_dict=df_cot.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_cot.to_json("train_cot.json", orient="records", lines=True)
with open('train_cot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_cot.head()
# %pwd
# Out:
#                                                   input  output
# 0      Warning, this post contains an optimistic ant...       1
# 1      second one didn't make me sick but I had a GI...       1
# 2     Just got my flu shot and now experiencing some...       1
# 3     Has anyone experienced a strong reaction to th...       1
# 4      I have a very reactive immune system. 1 vacci...       1
# ...                                                 ...     ...
# 3302   This is to educate the community of HSV parti...       0
# 3303   While topicals are actually clearing up the p...       0
# 3304   We will refer to my wife as "J" Another woman...       0
# 3305   Almost 5 years ago, I was diagnosed with stag...       0
# 3306   Hello! I was hoping you could help me with so...       0
#
# [3307 rows x 2 columns]
# '/content'

# %%
# %cd /home1/00000/abcde/work/LLaMA-Factory/data
df_cot = pd.read_csv('valid 1_Task6.csv')

# Rename columns to match LlamaFactory format
df_cot = df_cot[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Chain-of-Thought instruction
cot_prompt = """Analyze the following Reddit post and determine if it contains a personal mention of an adverse reaction to the shingles vaccine.
Let's break down the reasoning step by step:

1. Identify if the post is written from personal experience (first-person or describing a specific individual).
2. Check if the post mentions any symptoms or side effects following a shingles vaccination.
3. If both conditions are met, the post is a personal adverse reaction account.

Finally, provide the classification as '1' (contains a personal adverse reaction mention) or '0' (does not), along with a brief explanation of your reasoning."""

# Add prompt as in-context learning
df_cot['instruction'] = cot_prompt
df_dict=df_cot.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_cot.to_json("train_cot.json", orient="records", lines=True)
with open('valid_cot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_cot.head()
# Out:
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# /work/00000/abcde/LLaMA-Factory/data
#                                                input output  \
# 0  1st shingles shot over 72 hours ago and still ...      1
# 1  Shingles Vaccine: I got it. Kicked my butt for...      1
# 2  Shingles vaccine: second dose: 2nd got me, fir...      1
# 3  Shingles vaccine: second dose: 2nd one was not...      1
# 4  Shingles vaccine: second dose: First one level...      1
#
#                                          instruction
# 0  Analyze the following Reddit post and determin...
# 1  Analyze the following Reddit post and determin...
# 2  Analyze the following Reddit post and determin...
# 3  Analyze the following Reddit post and determin...
# ...

# %% [markdown]
# CoT-updated

# %%
#%cd /content/drive/MyDrive/SMM4H/Task6/New
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
#%cd /home/UNT/fs0199//LLaMA-Factory/data/smm4h/
df_cot = pd.read_csv('train_final_Task6.csv')

# Rename columns to match LlamaFactory format
df_cot = df_cot[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Chain-of-Thought instruction
cot_prompt = """Analyze the following Reddit post and determine if it contains a personal account of an adverse reaction to the shingles vaccine. To decide, follow these steps:

1. Check for first-hand experience cues (e.g., first-person pronouns such as "I", "my", or specific references indicating personal experience).
2. Look for an explicit statement that the individual received the shingles vaccine.
3. Identify any mention of side effects or adverse reactions following the vaccination.
4. Evaluate the context: if the language is ambiguous or merely speculative, lean towards a classification of '0'.

After considering these points, provide your answer as:
- '1' if the post clearly includes a personal account of adverse reactions.
- '0' if it does not.
Finally, include a brief explanation of your reasoning.

Now, classify the following post accordingly."""

# Add prompt as in-context learning
df_cot['instruction'] = cot_prompt
df_dict=df_cot.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_cot.to_json("train_cot.json", orient="records", lines=True)
with open('train_cot_final.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_cot.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input output  \
# 0  Shingles Vaccine: Warning, this post contains ...      1
# 1  Going to get my 2nd shingles shot in 15 minute...      1
# 2  Just got my flu shot and now experiencing some...      1
# 3  Has anyone experienced a strong reaction to th...      1
# 4  Getting two vaccines at once: I have a very re...      1
#
#                                          instruction
# 0  Analyze the following Reddit post and determin...
# 1  Analyze the following Reddit post and determin...
# 2  Analyze the following Reddit post and determin...
# 3  Analyze the following Reddit post and determin...
# ...

# %%
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df_cot = pd.read_csv('test_task6.csv')

# Rename columns to match LlamaFactory format
df_cot = df_cot[['text']].rename(columns={'text': 'input'}).astype(str)

# Chain-of-Thought instruction
cot_prompt = """Analyze the following Reddit post and determine if it contains a personal account of an adverse reaction to the shingles vaccine. To decide, follow these steps:

1. Check for first-hand experience cues (e.g., first-person pronouns such as "I", "my", or specific references indicating personal experience).
2. Look for an explicit statement that the individual received the shingles vaccine.
3. Identify any mention of side effects or adverse reactions following the vaccination.
4. Evaluate the context: if the language is ambiguous or merely speculative, lean towards a classification of '0'.

After considering these points, provide your answer as:
- '1' if the post clearly includes a personal account of adverse reactions.
- '0' if it does not.
Finally, include a brief explanation of your reasoning.

Now, classify the following post accordingly."""

# Add prompt as in-context learning
df_cot['instruction'] = cot_prompt
df_dict=df_cot.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_cot.to_json("train_cot.json", orient="records", lines=True)
with open('test_cot_final.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_cot.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input  \
# 0  Just got my flu shot last month and now I'm ex...
# 1  If you had chicken pox as a child you need to ...
# 2  "Vaccine reaction causing shingles reoccurrenc...
# 3  I am a 34F and 14 weeks pregnant with a health...
# 4  If you had chicken pox as a child you need to ...
#
#                                          instruction
# 0  Analyze the following Reddit post and determin...
# 1  Analyze the following Reddit post and determin...
# 2  Analyze the following Reddit post and determin...
# 3  Analyze the following Reddit post and determin...
# ...

# %% [markdown]
# fs-cot

# %%
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df_cot = pd.read_csv('train_new_Task6.csv')

# Rename columns to match LlamaFactory format
#df_cot = df_cot[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Chain-of-Thought instruction
cot_prompt = """Analyze the following Reddit post and determine if it contains a personal account of an adverse reaction to the shingles vaccine. To decide, follow these steps:

1. Check for first-hand experience cues (e.g., first-person pronouns such as "I", "my", or specific references indicating personal experience).
2. Look for an explicit statement that the individual received the shingles vaccine.
3. Identify any mention of side effects or adverse reactions following the vaccination.
4. Evaluate the context: if the language is ambiguous or merely speculative, lean towards a classification of '0'.

Example 1:
Post: "I got my shingles vaccine last week, and now I have a severe headache and nausea."
Reasoning:
- "I" indicates a first-hand account.
- Clearly states receipt of the vaccine.
- Mentions specific side effects.
Final Classification: 1

Example 2:
Post: "Heard that the shingles vaccine might cause side effects."
Reasoning:
- No first-person perspective or personal experience.
- Lacks clear evidence of receiving the vaccine.
Final Classification: 0

Now, using the same process, classify the following post"""

# Add prompt as in-context learning
df_cot['instruction'] = cot_prompt
df_dict=df_cot.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_cot.to_json("train_cot.json", orient="records", lines=True)
with open('train_fs-cot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_cot.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input  output  \
# 0   Warning, this post contains an optimistic ant...       1
# 1   second one didn't make me sick but I had a GI...       1
# 2  Just got my flu shot and now experiencing some...       1
# 3  Has anyone experienced a strong reaction to th...       1
# 4   I have a very reactive immune system. 1 vacci...       1
#
#                                          instruction
# 0  Analyze the following Reddit post and determin...
# 1  Analyze the following Reddit post and determin...
# 2  Analyze the following Reddit post and determin...
# 3  Analyze the following Reddit post and determin...
# ...

# %%
# %cd /home1/00000/abcde/work/LLaMA-Factory/data/New
df_cot = pd.read_csv('valid_new_Task6.csv')

# Rename columns to match LlamaFactory format
#df_cot = df_cot[['text', 'labels']].rename(columns={'text': 'input', 'labels': 'output'}).astype(str)

# Chain-of-Thought instruction
cot_prompt = """Analyze the following Reddit post and determine if it contains a personal account of an adverse reaction to the shingles vaccine. To decide, follow these steps:

1. Check for first-hand experience cues (e.g., first-person pronouns such as "I", "my", or specific references indicating personal experience).
2. Look for an explicit statement that the individual received the shingles vaccine.
3. Identify any mention of side effects or adverse reactions following the vaccination.
4. Evaluate the context: if the language is ambiguous or merely speculative, lean towards a classification of '0'.

Example 1:
Post: "I got my shingles vaccine last week, and now I have a severe headache and nausea."
Reasoning:
- "I" indicates a first-hand account.
- Clearly states receipt of the vaccine.
- Mentions specific side effects.
Final Classification: 1

Example 2:
Post: "Heard that the shingles vaccine might cause side effects."
Reasoning:
- No first-person perspective or personal experience.
- Lacks clear evidence of receiving the vaccine.
Final Classification: 0

Now, using the same process, classify the following post"""

# Add prompt as in-context learning
df_cot['instruction'] = cot_prompt
df_dict=df_cot.to_dict(orient="records")
# Save as JSON (Alpaca format for LlamaFactory)
#df_cot.to_json("train_cot.json", orient="records", lines=True)
with open('valid_fs-cot.json', 'w') as f:
    json.dump(df_dict, f, indent=4)
# Display sample
df_cot.head()
# Out:
# /work/00000/abcde/LLaMA-Factory/data/New
# /home1/00000/abcde/work/anaconda3/envs/llamafactory/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
#                                                input  output  \
# 0                          Second shot sucks too....       1
# 1       I got it. Kicked my butt for about 36 hours.       1
# 2   second dose: 2nd got me, first was fine. YMMV...       1
# 3   second dose: 2nd one was not as bad as the fi...       1
# 4   second dose: First one leveled me; second one...       1
#
#                                          instruction
# 0  Analyze the following Reddit post and determin...
# 1  Analyze the following Reddit post and determin...
# 2  Analyze the following Reddit post and determin...
# 3  Analyze the following Reddit post and determin...
# ...

# %% [markdown]
# Examples:
# 1. Post: "I got my shingles vaccine last week and now I’m experiencing a high fever and nausea." → 1
# 2. Post: "Why do some people get fatigue after the shingles vaccine?" → 0
# 3. Post: "My husband had severe arm pain for days after his Shingrix dose." → 1
# 4. Post: "Heard that the shingles vaccine might cause side effects." → 0

# %% [markdown]
# --------------------------------------------------------------------------------
# End Line
